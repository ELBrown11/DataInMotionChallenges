# %% [markdown]
# # **Challenge 3: Alcohol Consumption**

# %%
#import libraries
import pandas as pd

# %%
#data url
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'

# %%
#read in data
data = pd.read_csv(url)
data.head()#preview data
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %% [markdown]
# # **Questions**

# %% [markdown]
# 1. Which continent drinks more beer on average?

# %%
avg_drinks = data.groupby(by='country')['total_litres_of_pure_alcohol'].mean().sort_values(ascending=False)
avg_drinks
# Out:
# country
# Belarus       14.4
# Lithuania     12.9
# Andorra       12.4
# Grenada       11.9
# France        11.8
#               ...
# Maldives       0.0
# Kuwait         0.0
# Iran           0.0
# Bangladesh     0.0
# Libya          0.0
# Name: total_litres_of_pure_alcohol, Length: 193, dtype: float64

# %% [markdown]
# 2. For each continent print the statistics for wine consumption.

# %%
wine_continent = data[['continent','wine_servings']]
wine_continent
# Out:
#     continent  wine_servings
# 0          AS              0
# 1          EU             54
# 2          AF             14
# 3          EU            312
# 4          AF             45
# ..        ...            ...
# 188        SA              3
# 189        AS              1
# 190        AS              0
# 191        AF              4
# 192        AF              4
#
# [193 rows x 2 columns]

# %%
for i in range(len(wine_continent)):
  print(wine_continent.iloc[[i]])
# Out:
#   continent  wine_servings
# 0        AS              0
#   continent  wine_servings
# 1        EU             54
#   continent  wine_servings
# 2        AF             14
#   continent  wine_servings
# 3        EU            312
#   continent  wine_servings
# 4        AF             45
#   continent  wine_servings
# 5       NaN             45
#   continent  wine_servings
# 6        SA            221
#   continent  wine_servings
# 7        EU             11
#   continent  wine_servings
# 8        OC            212
#   continent  wine_servings
# 9        EU            191
#    continent  wine_servings
# 10        EU              5
#    continent  wine_servings
# 11       NaN             51
#    continent  wine_servings
# 12        AS              7
#    continent  wine_servings
# 13        AS              0
#    continent  wine_servings
# 14       NaN             36
#    continent  wine_servings
# 15        EU             42
#    continent  wine_servings
# 16        EU            212
# ...

# %% [markdown]
# 3. Print the mean alcohol consumption per continent for every column.

# %%
avg_drinks_cont = data.groupby(by='continent')['total_litres_of_pure_alcohol'].mean()
avg_drinks_cont
# Out:
# continent
# AF    3.007547
# AS    2.170455
# EU    8.617778
# OC    3.381250
# SA    6.308333
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
for i in range(len(avg_drinks_cont)):
  print(avg_drinks_cont.iloc[[i]])
# Out:
# continent
# AF    3.007547
# Name: total_litres_of_pure_alcohol, dtype: float64
# continent
# AS    2.170455
# Name: total_litres_of_pure_alcohol, dtype: float64
# continent
# EU    8.617778
# Name: total_litres_of_pure_alcohol, dtype: float64
# continent
# OC    3.38125
# Name: total_litres_of_pure_alcohol, dtype: float64
# continent
# SA    6.308333
# Name: total_litres_of_pure_alcohol, dtype: float64

# %% [markdown]
# 4. Print the median alcohol consumption per continent for every column.

# %%
med_drinks_cont = data.groupby(by='continent')['total_litres_of_pure_alcohol'].median()
med_drinks_cont
# Out:
# continent
# AF     2.30
# AS     1.20
# EU    10.00
# OC     1.75
# SA     6.85
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
for i in range(len(med_drinks_cont)):
  print(med_drinks_cont.iloc[[i]])
# Out:
# continent
# AF    2.3
# Name: total_litres_of_pure_alcohol, dtype: float64
# continent
# AS    1.2
# Name: total_litres_of_pure_alcohol, dtype: float64
# continent
# EU    10.0
# Name: total_litres_of_pure_alcohol, dtype: float64
# continent
# OC    1.75
# Name: total_litres_of_pure_alcohol, dtype: float64
# continent
# SA    6.85
# Name: total_litres_of_pure_alcohol, dtype: float64
